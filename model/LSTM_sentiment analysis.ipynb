# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import font_manager
from itertools import accumulate

# 设置matplotlib绘图时的字体
my_font = font_manager.FontProperties(fname="/Library/Fonts/Songti.ttc")

# 统计句子长度及长度出现的频数
df = pd.read_csv('../Data/data_single.csv')
print(df.groupby('label')['label'].count())

df['length'] = df['evaluation'].apply(lambda x: len(x))
len_df = df.groupby('length').count()
sent_length = len_df.index.tolist()
sent_freq = len_df['evaluation'].tolist()

# 绘制句子长度及出现频数统计图
plt.bar(sent_length, sent_freq)
plt.title("句子长度及出现频数统计图", fontproperties=my_font)
plt.xlabel("句子长度", fontproperties=my_font)
plt.ylabel("句子长度出现的频数", fontproperties=my_font)
# plt.savefig("./句子长度及出现频数统计图.png")
plt.close()

# 绘制句子长度累积分布函数(CDF)
sent_pentage_list = [(count/sum(sent_freq)) for count in accumulate(sent_freq)]

# 绘制CDF
plt.plot(sent_length, sent_pentage_list)

# 寻找分位点为quantile的句子长度
quantile = 0.91
#print(list(sent_pentage_list))
for length, per in zip(sent_length, sent_pentage_list):
    if round(per, 2) == quantile:
        index = length
        break
print("\n分位点为%s的句子长度:%d." % (quantile, index))

# 绘制句子长度累积分布函数图
plt.plot(sent_length, sent_pentage_list)
plt.hlines(quantile, 0, index, colors="c", linestyles="dashed")
plt.vlines(index, 0, quantile, colors="c", linestyles="dashed")
plt.text(0, quantile, str(quantile))
plt.text(index, 0, str(index))
plt.title("句子长度累积分布函数图", fontproperties=my_font)
plt.xlabel("句子长度", fontproperties=my_font)
plt.ylabel("句子长度累积频率", fontproperties=my_font)
# plt.savefig("../Data/句子长度累积分布函数图.png")
plt.close()
# Out:
# label
# 正面    1908
# 负面    2375
# Name: label, dtype: int64
#
# 分位点为0.91的句子长度:183.

# %%
import pickle
import numpy as np
import pandas as pd
from keras.utils import np_utils, plot_model
from keras.models import Sequential
from keras.preprocessing.sequence import pad_sequences
from keras.layers import LSTM, Dense, Embedding, Dropout
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# 导入数据
# 文件的数据中，特征为evaluation, 类别为label.
def load_data(filepath, input_shape=20):
    df = pd.read_csv(filepath)

    # 标签及词汇表
    labels, vocabulary = list(df['label'].unique()), list(df['evaluation'].unique())

    # 构造字符级别的特征
    string = ''
    for word in vocabulary:
        string += word

    vocabulary = set(string)

    # 字典列表
    word_dictionary = {word: i+1 for i, word in enumerate(vocabulary)} # enumerate() 函数用于将一个可遍历的数据对象(如列表、元组或字符串)组合为一个索引序列，同时列出数据和数据下
    with open('word_dict.pk', 'wb') as f:
        pickle.dump(word_dictionary, f) # 序列化对象，将对象obj保存到文件file中去
    inverse_word_dictionary = {i+1: word for i, word in enumerate(vocabulary)}
    label_dictionary = {label: i for i, label in enumerate(labels)}
    with open('label_dict.pk', 'wb') as f:
        pickle.dump(label_dictionary, f)
    output_dictionary = {i: labels for i, labels in enumerate(labels)}

    vocab_size = len(word_dictionary.keys()) # 词汇表大小
    label_size = len(label_dictionary.keys()) # 标签类别数量

    # 序列填充，按input_shape填充，长度不足的按0补充
    x = [[word_dictionary[word] for word in sent] for sent in df['evaluation']]
    x = pad_sequences(maxlen=input_shape, sequences=x, padding='post', value=0)
    y = [[label_dictionary[sent]] for sent in df['label']]
    y = [np_utils.to_categorical(label, num_classes=label_size) for label in y]
    y = np.array([list(_[0]) for _ in y])

    return x, y, output_dictionary, vocab_size, label_size, inverse_word_dictionary

# 创建深度学习模型， Embedding + LSTM + Softmax.
def create_LSTM(n_units, input_shape, output_dim, filepath):
    x, y, output_dictionary, vocab_size, label_size, inverse_word_dictionary = load_data(filepath)
    model = Sequential()
    model.add(Embedding(input_dim=vocab_size + 1, output_dim=output_dim,
                        input_length=input_shape, mask_zero=True))
    model.add(LSTM(n_units, input_shape=(x.shape[0], x.shape[1])))
    model.add(Dropout(0.2))
    model.add(Dense(label_size, activation='softmax'))
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

    plot_model(model, to_file='./model_lstm.png', show_shapes=True)
    model.summary()

    return model

# 模型训练
def model_train(input_shape, filepath, model_save_path):

    # 将数据集分为训练集和测试集，占比为9:1
    # input_shape = 100
    x, y, output_dictionary, vocab_size, label_size, inverse_word_dictionary = load_data(filepath, input_shape)
    train_x, test_x, train_y, test_y = train_test_split(x, y, test_size = 0.1, random_state = 42)

    # 模型输入参数，需要自己根据需要调整
    n_units = 100
    batch_size = 32
    epochs = 5
    output_dim = 20

    # 模型训练
    lstm_model = create_LSTM(n_units, input_shape, output_dim, filepath)
    lstm_model.fit(train_x, train_y, epochs=epochs, batch_size=batch_size, verbose=1)

    # 模型保存
    lstm_model.save(model_save_path)

    N = test_x.shape[0]  # 测试的条数
    predict = []
    label = []
    for start, end in zip(range(0, N, 1), range(1, N+1, 1)):
        sentence = [inverse_word_dictionary[i] for i in test_x[start] if i != 0]
        y_predict = lstm_model.predict(test_x[start:end])
        label_predict = output_dictionary[np.argmax(y_predict[0])]
        label_true = output_dictionary[np.argmax(test_y[start:end])]
        print(''.join(sentence), label_true, label_predict) # 输出预测结果
        predict.append(label_predict)
        label.append(label_true)

    acc = accuracy_score(predict, label) # 预测准确率
    print('模型在测试集上的准确率为: %s.' % acc)


filepath = '../Data/data_single.csv'
input_shape = 180
model_save_path = './corpus_model.h5'
model_train(input_shape, filepath, model_save_path)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_2 (Embedding)      (None, 180, 20)           43100
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 100)               48400
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 100)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 2)                 202
# =================================================================
# Total params: 91,702
# Trainable params: 91,702
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/5
# 3854/3854 [==============================] - 22s 6ms/step - loss: 0.4298 - acc: 0.8064
# Epoch 2/5
# 3854/3854 [==============================] - 19s 5ms/step - loss: 0.2196 - acc: 0.9273
# Epoch 3/5
# 3854/3854 [==============================] - 19s 5ms/step - loss: 0.1825 - acc: 0.9447
# Epoch 4/5
# 3854/3854 [==============================] - 19s 5ms/step - loss: 0.1501 - acc: 0.9546
# Epoch 5/5
# 3854/3854 [==============================] - 19s 5ms/step - loss: 0.1318 - acc: 0.9582
# 硬件一般，但是软件很棒， 负面 负面
# 客服态度好。电视还没有开始用，还不知道效果。用了再评价 正面 负面
# 对的起这样的价钱 支持京东 想要下单的亲可以放心下单 加油 语音遥控器没有 希望京东送一个 谢谢 负面 负面
# 非常差，8月8日1元预购的电视礼包，说不发就不发了，真是非常差劲，真后悔在这家店买东西，大家不要再来了。 负面 负面
# 京东物流慢了些，本来应该昨天送到的，结果今天才送到。电视还可以，稍微有点延迟，性价比很高。 负面 负面
# 后还选择了这个创维一些国产的品牌，但是仔细参考参数之后还是做出了一个大胆的选择，选择的微鲸，使用了，之后的感觉非常的不错，老婆也非常的喜欢，感觉比那个乐视的话还是有一定的优势。可惜的话就是会员不够多，然后的话价格稍微贵了一点，现在可能那个平板液晶平板这一块也涨价了，所以说这个也情有可原。喜欢的可以大胆下手了，不会失望的，至少比创维，海信要好多了…性价比更高！ 负面 负面
# 卧室用的，画面挺清晰，但是不能离近看，否则颜色会很诡异，安装师傅挺好的 正面 正面
# 挺薄的外观挺漂亮，色彩还行，就是有拖影清晰度不够好，这点挺不满意，。问客服问题反应太慢了半天才回答。 负面 负面
# 不错，挺好的，真不错很喜欢 正面 正面
# 到货非常快，运行速度快，界面清晰，非常好。 正面 正面
# 总的来说对这款机器不满意，漏光严重，厂家说不属于质量问题。 负面 负面
# 开机稍微有些慢，其他都蛮好的。当天送回，棒 负面 负面
# 太差。送支架活动简直是给客户添堵的，收到电视没有赠送的支架，无法安装。联系客服说收货后7日发，第3天跟进，说没有登记需要登记确认后7日后再发。本来很简单的事情，商家可以申请售后安装免除支架费给客户提供方便，现在弄得电视放家里10天都没法安装。看网上都是因为支架给差评的。一个产品没有好的服务，必然不会长久，也许不久商业教科书会有一个支架毁了一个品牌的经典案例。 负面 负面
# 特别喜欢，很大，很清晰，特别实惠，活动的时候买的。 正面 正面
# 电视整体还是满意，说说不满意的地方，1电视开机系统准备太频繁，时间两分钟左右，感觉很窝心，2习惯了使用机顶盒遥控器，此电视遥控器不能被学习，如果看机顶盒直播节目就得用两个遥控器，很不方便。其他因为才使用还没发现。 负面 负面
# 适用了几天，画质不错，看高清没有拖影现象，机身金色的边框看着也很大气。电视买给父母看。只是有一点不太满意。6月1日秒杀时候都不能能用满2000减100的券，后来的秒杀都能用券了，等于买贵了100。郁闷。 负面 负面
# 安装师傅很负责，说是空心墙，多加了几颗螺丝固定。电视试看了下感觉不错。 晒单： 收起 向左转 向右转 正面 正面
# 买电器到京东还是可信的！发货速度快，第二天货已经收到了。电视机的清晰度很好 正面 正面
# 过来了。送货师傅也很耐心的帮我验货，看看外观有没有损伤，电视能不能正常开机，试完后还帮我把包装盒重新装上，像刚送来的一样。非常好。 最后，安装师傅也很好，由于预约的时间到了下午，可能他来不及来帮我安装，但是他竟然在过了下班时间加班来帮我把电视装好，装好之后也帮我把盒子这些都调试好了，真是非常赞。 总之，这次的电视买得很赞，服务也很好。感谢送货师傅和安装师傅！ 正面 正面
# 双11，2549入手，两千多的电视做到这份上，真的蛮不错了啊。 正面 正面
# 不错。。。。。 正面 正面
# 除了开机慢点以外，其他都还能接受，基本算是物美价廉吧，京东自营的电器可以放心。唯一的遗憾是网络不行，无法刷卡支付。京东帮工作人员很给力，好评。 负面 负面
# 这个总开关在电视机的右下角，不能用遥控器关，这点不是很好。语音点播功能试了下还不错，挺精准。看户外节目是感觉画质不是很清晰，颜色有点艳，其他暂时还没发现什么，价格很便宜，希望质量能有保证 负面 负面
# 电视不错，外观也漂亮，好评好评。 正面 正面
# 买了两款电视，55寸的表现出众，性能强劲，性价比很有诱惑力。这款32寸的就稍显不足，款式陈旧，性能一般，价钱没优势，略感遗憾。 负面 负面
# 很好很好，很实惠 正面 正面
# 老顾客了，非常满意！ 正面 正面
# 确实是没有辜负期望，值得购买，信赖大！ 正面 正面
# 电视刚开始开机有点慢，后来更新系统以后就没这个问题了。总体来说不错，之前买过一台TCL，感觉和老牌的机器一样好 负面 负面
# 对微鲸有些失望，画质没有想象的好，会员也看不了啥 负面 负面
# 后还选择了这个创维一些国产的品牌，但是仔细参考参数之后还是做出了一个大胆的选择，选择的微鲸，使用了，之后的感觉非常的不错，老婆也非常的喜欢，感觉比那个乐视的话还是有一定的优势。可惜的话就是会员不够多，然后的话价格稍微贵了一点，现在可能那个平板液晶平板这一块也涨价了，所以说这个也情有可原。喜欢的可以大胆下手了，不会失望的，至少比创维，海信要好多了…性价比更高！ 负面 负面
# 电视机算不错，开机待频好慢，领取会员操作好麻烦，几天了至今没领。 负面 负面
# 其他都可以，就是wifi连接上了不能看视频 负面 负面
# 开箱通电后没啥问题，送货的师傅还是很负责的。曲面屏的确上档次。自己上几颗螺丝安装了，希望不要出问题。 正面 负面
# 物流及服务都特别棒，更棒的是售后服务，给你们点赞 正面 正面
# 不错，就是系统不太好，不适合老人操作 负面 负面
# 这个hdr我也找不到，不会用还没有研究透，等有空再研究。送货很及时，上午收到货下午安装师傅到了，安装师傅装的很用心，服务态度很好 负面 正面
# 发货快，送货上门，当场拆箱验屏幕；小米刚出了32寸1099元，最近降100元，但是要预约，所以买了这款；比小米32寸款好的就是内存8G喇叭声更响送一年会员；缺点如下：电视机太厚不够薄，系统不好用不够人性化爸妈嫌麻烦，安装的直播软件设置开机重启，不能自启！ 负面 负面
# 物流真快头天下单第二天就到了比某 保强多了 正面 正面
# 觉得一般，画面清晰度不高。其他还是 负面 负面
# 显示效果一般，色彩过度不平滑，语音功能比较鸡助，不过价格合适，性价比比较高。 负面 负面
# 非常漂亮的电视机，比商场便宜多了，可以的 正面 正面
# 第二台微鲸电视，性价比高，轻微漏光，比去年贵了不少 负面 负面
# 很清晰，蛮好的，价格一贵 负面 负面
# 发货前一天电话联系确定送货时间地址，送货师傅同时负责开箱验货并安装。这种品牌质量这种服务态度太赞啦??? 正面 负面
# 昨天到货，我不在家，特意请表弟试了数字电视，又试了网络，他说反应挺快的，内容丰富，性价比高，双12入手，真的很实惠！ 希望快点放假，守着电视，把好剧连连看！ 正面 正面
# 1.机子看了5天了，挺好的，符合描述的硬屏，大屏，较薄，14kg。 2.画面清晰，赠送一年的会员，可以看腾讯VIP，但是只有超清影片才能体现4k的画质。 3.可以通过小鹰直播看电视直播，系统自带，但是某些电视台的画质非常不好。 4.遥控器简洁好用，如图。但是赠送手环是营销手段，咨询客服说只有300名。早说.... 总体超值超值超值 负面 负面
# 速度太快了..昨天晚上下单下午就送过来了..快递小哥太给力了..正品 正面 正面
# 我的型号是创维65寸H7超薄的 昨天刚开机 电视给我感觉就是小了一点 我本来打算放客厅 现在放 卧室了 我房间要买创维100寸的蓝牙遥控器 随意切换一点都不卡，点什么都是秒出来 好看 大气我还要 再买一台100寸的.真的好喜欢他的架子 就是好看 不卡 大气 买的你放心 买的你安心 买的你绝对不后悔走过路过 千万别错过 支持买 买买 差不多了 我去忙了 非常好 正面 负面
# 电视效果还不错，性价比可以接受，刚开始播放高清片源时，有一点卡。电视放在桌子上，稍微有点单薄，有孩子还得挂起来比较安全。快递稍微有点慢，不过事出有因，总体说的过去吧。 负面 负面
# 非常超值的平板电视，大小刚合适，4K高清确实效果好，操作方便，片源丰富，百事通很爽，再买两个小的放卧室，绝对的高性价比之王，买对了。 正面 正面
# 就不上图了 一句话还不错 正面 负面
# 电视不错，很喜欢 正面 正面
# 感觉买小了点，还是能看，正品 正面 负面
# ，但是仅仅出现了一次，后来经过咨询客服，重新连就好了，语音识别率很高，赞一个。总的说来，这款电视有几个优势：首先是创维品牌，售后有保障，大品牌值得信赖；其次就是性价比，在这个价位能买这个配置和尺寸的，估计也只能买其他一些非主流牌子；第三，颜值和配置都比较高；第四，京东的服务不错，物流也快。综合以上几点，客观的说，这款电视非常值得入手，想入手的小伙伴抓紧入手! 正面 负面
# 外观大气，系统流畅。内置工具丰富，购物非常满意！ 正面 正面
# 利用蓝牙智能遥控器语音操作，识别率高，快捷实用，值得称赞。微鲸Live里面有不少4K资源，只是没注册会员暂不能观看，以后再追评吧。客服态度不错，有问必答。不足之处因为是国产硬屏，色彩的艳丽度不如进口屏；另外USB等外用接口数量偏少了些，使用上稍显不便。考虑到购买消费群的年龄段，在促销活动时，如果能赠送配套的游戏手柄，那么竞争力无疑会更强。总体好评，值得推荐! 负面 负面
# 点17分打售后电话预约安装。售后一直没有和我们联系！老公早上又自己打电话去主动联系，售后说他们系统没有登记，让我们等着他们再安排，我就和京东售前联系，售前也不管，只会像复读机一样让我自己找售后.。真是够了，实在忍不了给了差评。要买的亲慎重，东西我确实还没有用不知道效果，但是服务确实不敢恭维，受得气的再考虑购买哈！本来一星也不想给，但是选择不了零星！气的我胃疼 负面 负面
# 价格实惠功能强悍。 正面 正面
# 开关机没有广告，是选择微鲸的原因。电视的外观和画质还不错，喇叭效果和遥控语音效果不太理想，但对于不到3000的价位，还算不错? 负面 负面
# 55英寸大屏，清晰。送货小哥辛苦了。唯一不足是支架不算太稳，有点摇晃。片源不少，系统反应也快，下次还会选择微鲸。 负面 负面
# 电视挺好的，暂时没什么问题，反应有点慢，内存加1g就完美了 负面 负面
# 对比了很多家产品. 最终选择了新兴品牌微鲸. 电视4天送到 相比起来较慢. 送货态度很不好. 好像谁欠他钱似的. 电视外包装箱被雨淋湿了. 都坏了. 电视整体还凑合吧. 没有很惊艳. 如果需要放在电视柜上 柜长要140cm以上. 能玩的游戏有限.而且都是小游戏. 总体不太值 负面 负面
# 物流很快，就是安装费有点贵，要是免费安装就更好了，总的来说还不错 正面 负面
# 差评 服务态度差 搞活动还有内幕 负面 负面
# 老公帮叔叔买的~小米的品牌一直喜欢 这次价格还可以 正面 正面
# 很好，很不错 正面 正面
# 还不错感觉、哈哈哈。用几个月看看 好在追评 正面 正面
# 不错 正面 正面
# 买个了5000块的的电视，结果因为客服问题。电视到了几天放等个挂架。你挂架和电视分开送就算了，明明是下单就可以登记发货挂架的。结果跟我说收到货才登记。就算收货登记也就算了，发货还要7个工作日。这是什么概念？起码12天。垃圾的微鲸，再也不买你们产品了 负面 负面
# 4K MEMC，色彩好，拥有HDR技术，广色域技术，4K MEMC，画质清晰音质也还好 杜比解码+DTS解码，立体环绕音效，搭载酷开系统5.8。再有就是安装师傅，安装角度和尺寸，他会根据你家的空调位置和电视柜还有灯的整体位置效果，来确定你是否满意放到的尺寸，真的很专业，经过和你沟通好，确定安装位,而且京东还送了支架，免费的呢！就是感觉电视买小了．总之很满意！ 正面 正面
# 风行互联网电视收到已有一周，认真做出一下评价，京东配送效率奇高。农村网点全覆盖无死角，免费安装，免费调试。电视清晰自然，远超逾期，属于京东商城性价比最高的电视。操作简单，内容丰富多彩，老少皆宜的操作风格，风行值得拥有。下次要买就买风行的量子电视。介绍就是高大上。谁看谁知道。 正面 正面
# 看起来还不错，接口少点，没VGA口 负面 负面
# 小米电视性价比高，暂时还没有使用，测试是OK的 正面 正面
# 电视特别好，很清晰，物流也很快，赞一个 正面 正面
# 金属边框，背板是塑料的，较厚，价格还行吧，网络还没到位就开机试了一下，总体满意 负面 负面
# 已联系挂墙安装完成，服务不错，就是侧面看上去有点厚，但价格确实便宜啊。 正面 负面
# 塌头，做工粗糙，工具质量差，拧几下就变形了。螺丝一堆，我就问问怎么跟安装说明不一样，少了4个，客服非常没耐心！就一句‘’螺丝都一样的‘’就消失了！我连问三句都没搭理我！ 负面 负面
# 又11买下的，优惠了一点，外观蛮大气的。 正面 正面
# 微信服务号设计有问题无法预约安装，客服电话占线打不通。联系京东客服，还是推来推去，售后真差！！！！不是一般的差！给一星都多！ 负面 负面
# 非常好 正面 正面
# 感觉很好，12号1点买的，早上九点就送到位，下午售后进行了安装调试，很大，家人都很喜欢，支持国货！ 正面 正面
# 给妈妈买的送货超级快，免费安装，送货人员服务也很热情，安装师傅很用心，给妈妈耐心讲解，妈妈说画面很清晰，内容也很丰富，在家里放着也不大，不占地方，挺好的电视 正面 正面
# 送货速度快，刚刚装好，声音效果不好，屏幕显示效果一般 负面 负面
# 画质还可以 但是语音功能根本不能用 忽悠人 打400微鲸客服 派人过来也是回复出厂设置而已 失灵时不灵 我主要看语音控制才买的 没想到只是个噱头而已 很不满意 给差评只是对语音来说 其他的都满意 没有坏点 另外电视功耗高 发热量很大 不要相信视屏秀 骗人的 负面 负面
# 物流是真快，但是悲催的是少了底架上的螺丝配件，电视安装不起来，所以还不知道电视怎么样哦，就等着一个小小螺丝配件了，好几天了还没到，能快点不 负面 负面
# 电视不错。主要是便宜 正面 正面
# 差评 很不满意 当时的活动是送挂架 结果没送 售后用50来抵 还有问我要当时活动页面的截图！ 限时活动还来个限量 负面 负面
# 大品牌 防静电包装 值得信赖！ 正面 正面
# 差评，6月1日下单，定的24号送货，618的时候看到可以送支架，问客服我下的订单是否送支架，当时想如果不送就重新下个单，客服回复说送。送货的时候没有收到支架，再问客服，客服说根据订单编号查询，不送支架，真是晕。第一次问你们的时候怎么不根据订单编号来查询，就直接说送。等送货了，又说不送，毫无信用可言。 负面 负面
# 东西可以，配送物流对接不好。需望改进。 负面 负面
# 第二次购买，觉得微鲸的电视不错，资源还算丰富，就是没有直播，这点比较不满意，其他都比较满意！ 负面 负面
# 画质挺清晰的，便宜 正面 正面
# 挺好的，物流也快，两天就到了 正面 正面
# 功能方便，体验还好。价格便宜。 但是屏幕素质不好，左下角严重漏光。 负面 负面
# 因房子装修没有结束，还没有安装试用，电视机通电试了情况良好，售后服务也不错，啇家服务很好?，等正常使用了再来追评。 正面 正面
# 感觉不错，性价比不错，功能挺多，就是遥控器没有九键，有点不开森 负面 负面
# 使用ios对微鲸电视投屏 部分软件不支持全屏播放。我在家用Youtube对微鲸电视投屏 拿网页看不全屏可以正常播放，如果点全屏的时候微鲸就黑屏 进度条也不移动过了2~3秒 微鲸就闪退到主界面了。希望技术大大能解决一下，十分感谢！！ 负面 负面
# 利用蓝牙智能遥控器语音操作，识别率高，快捷实用，值得称赞。微鲸Live里面有不少4K资源，只是没注册会员暂不能观看，以后再追评吧。客服态度不错，有问必答。不足之处因为是国产硬屏，色彩的艳丽度不如进口屏；另外USB等外用接口数量偏少了些，使用上稍显不便。考虑到购买消费群的年龄段，在促销活动时，如果能赠送配套的游戏手柄，那么竞争力无疑会更强。总体好评，值得推荐! 负面 负面
# 第二台，只不过今年的价格是出奇的高了 负面 负面
# 很满意的一次购物体验，京山县服务店店家耐心负责确保了东西安全到家。以后家里用的还会上京东购买。 正面 正面
# 电视机播放效果很好，很满意 正面 正面
# 不错 正面 正面
# 双12买的电视～发货速度很快～第二天就送到家里了～当时打电话安装师傅很快就到了～外观很漂亮～图像清楚！关键是前期服务确实不错～ 正面 正面
# 太赞了！盛传商城神速，服务好，我本有点怀疑，但是亲经历了，让我知道，真的就是这么好。第一天下单，第二天就告诉我能安装了，这速度，不能再好了，只是我房子没装修好，暂缓2天来安装。客服好讲，服务周到，电视大气，画质超好，比实体店的4k电视要好多了，风行牌子真是不错，给个大赞！安装人员也是非常敬业，非常的棒，一次很好的购物体验！还没装宽带，装好了再来续评！ 正面 正面
# 留意微鲸好久了，一直等待活动入手。可惜越等越贵，今年电视全部都涨价了，6月果断入手。用着还不错，一到跟儿子一起打开，他很开心，可以看巧虎，挂架是找了楼下装空调的师傅打了墙孔，有钻头我就自己搞定了 负面 负面
# 质量很好！很高清，画面细腻，非常满意！ 正面 正面
# 这个大电视真是太好了 效果非常不错 买给父母很开心 已经看上了 我家的电视都是这个牌子 正面 正面
# 虽然电视很小众，但质量真心不错，比小米电视A4好多了，虽然比不上客厅的索尼大法，但屏幕清晰，色彩艳丽，性价比非常好，关键以后还有升级的可能，十分满意。 正面 正面
# 客服太傻，物流太慢，电视声音不如以前的小钢炮 负面 负面
# 个43寸.物流很快三四天就到了.因为新房当时正装修就改约到20日送货.物流的服务真好.跟踪服务很及时值得称赞.19号电视送到家插上电源试试画质很清晰.音质也很棒.只是55寸的两个小时后就黑屏开不了机.打400电话20号来人检查后开单联系客服重发一个电视过来.26号打开换的电视用了两天.家里人都说机器不错.立体感很强.微鯨电视、电视界的新秀.但愿有良好的表现. 负面 负面
# 根本不用预约呀，1198直接买的，非传统品牌，心情坎坷不安，咬牙下单试试，收货验过屏幕没事就自己装，4个螺丝而已。头三次开机好慢啊，最长的几乎5分钟，赶紧拨打客服电话，可能是系统更新，后来就好了，待机开机飞快，音画满意。总算安心了。连接移动硬盘居然连原盘也能放，强啊！ 负面 负面
# 相当不错的电视，就是下雨天送货慢了点，等到晚上才送货 负面 负面
# 严重不满意。开机也慢。最重要的是没得诚信，大家自己看，一点信誉也没得，哪个买了哪个后悔，大家自己看！ 负面 负面
# 简单，容易操作，不过电脑没有自带电视直播软件，应用商店也不能直接下载，还要找个电脑下载到优盘上，然后再安装，很不方便。 负面 负面
# 没有问题，很不错 正面 正面
# 第一次收到屏裂了，京东马上换一台新机重新发过来，赞一个！！ 负面 负面
# 质量不错，服务太度满意。 正面 正面
# 第一次在京东买大件，刚开始心里不大踏实，怕出现意外情况，结果还是挺满意的，送货小哥把电视给送到家里，开箱验货，通电联网，一切正常后才离开，在此非常感谢！电视效果也挺好的，第一次用智能电视有些功能还没有搞清楚，送的电视挂件和会员还没有到位，希望商家尽快安排！谢谢！ 负面 负面
# 价格便宜品质好，屏幕看电视很高清 正面 正面
# 挺好的，是我喜欢的！ 正面 正面
# 家人都喜欢这个电视，索尼还是可以的。 正面 正面
# 还行，但是屏幕感觉显示有问题 负面 负面
# 内容较多，操作方便，轻薄，不知是否耐用，待观察 正面 负面
# 点，来的时候都十点半了。开机后，在电视上扫码注册账号，用微信、qq、微信、手机号试了很多次，一提交就显示空白页面，换网站操作也一样。打客服电话，客服只会重复一样的话，最后还是在线客服微微帮忙注册的。电视本身不错，画面跟音响都可以，连接联通ip电视、硬盘、电脑都没问题，播放很流畅。而且接口都在一侧，插拔很方便。自己装的底座，电视太大不是特别稳定，准备换成挂架。 负面 负面
# 老顾客了，东西很好，会回购 正面 正面
# 电视到了，双十一买的虽然等了很久但是还是觉得很不错，感谢的送装服务，电视整体感觉很不错，色彩还原很好，声音试了下也不错，给老人买的应该很适合，速度很快！看了下配置，49寸的完全没毛病，推荐大家购买 正面 正面
# 基本上就是噱头，没有宣传中的那么好，基本没有任何改善，黑暗背景下四角全是白光，这应该就是传说中的漏光吧，omg。再就是背部的散热口，播放半个小时后能够明显感觉到很烫，很烫。再就是遥控器，缩水了，虽说评论后可以得到语音遥控器，可毕竟是迟来的爱啊。作为一个微鲸的老用户，冲着是对之前产品的良好体验才来再次购买的，而赤裸裸地标注是品牌高端系列，带来的体验确不敢恭维。 负面 负面
# 很快，关机要长按电源键再按确定键有些麻烦，按一下是待机，京东的送货师傅给调试的，服务超好，免费给安装了底座，调试了电视，还给帮忙把移动送的盒子也给装上了，不过挂机连架子要169有些贵了，希望能便宜些，现在电视柜没到暂时放地上看着，回头再喊师傅来挂起来。整体很满意，希望质量能靠得住~投屏，装软件都很方便，送的会员还没舍得用，客服说一年之内注册都可以，省着以后用 负面 负面
# 电视够大气 画面清晰 就是还不太会用 正面 负面
# 货收到，物流还是很给力的，现在试用还可以，继续关注 正面 正面
# 这电视不错，价钱便宜，服务一流，辛苦了快递员，要求加工资。 正面 负面
# 刚刚安装完，自己安装的，电视不错，唯一就是声音小，重音太轻其他的都不错。 负面 负面
# 很好的一次网购，快递速度超快，安装师傅服务很好，电视开机速度快，音质很优越，这个价格性价比超高，还送三年售后，极力推荐购买。不愧大厂出品。 正面 正面
# 自营家电品质有保证，暴风电视，非常实惠，性价比很高 正面 正面
# 除了开机太慢其他都很好 负面 负面
# 效果不错很好刚买回来就安装好了物流也很快 正面 正面
# ，半颗星都不想给，电视无法领取会员客服都无法解决，让打技术支持电话，打电话给技术支持，态度不错，告诉我也没办法解决，要下班了，第二天再找相关人员解决。电话过程中，旁边其他客服聊天声音特别大。 特别是京东回复客服，完全没有替客户解决问题的态度，微鲸客服严重需要培训啊。太失望了，本来抱很大希望的。这台机器肯定是退货后从新包装了又直接发过来的。账号已经被领取过了。 负面 负面
# 东西还不错，开箱插电，就是物流22号到的 我24号下午催的商家才送的货，物流不满意 负面 正面
# 不错，还送了一年会员，就是不知道那个wifi信号不好是不是自己的原因 负面 负面
# 1，4K电视，这个价格性价比太高了。 2，49寸放客厅就好大啊，看电影爽啊！ 3，操作不卡顿，不错 4，片源丰富，就电影区免费片源中都有太多太多好的豆瓣高分电影，这下看个够吧。 5，总之非常满意，性价比之王，诚心推荐！ 正面 负面
# 质量很好，画面很清晰 正面 正面
# 性价比还不错，蛮好的，买了好多台了 正面 正面
# 身，视觉无边框，25核处理器，2GDDR4+8GFLASH，配置好电视才能运行快；电视外表整体做工还行，拥有HDR技术，广色域技术，4KMEMC，色彩好，拥有HDR技术，广色域技术，4KMEMC，画质清晰音质也还好杜比解码+DTS解码，立体环绕音效，搭载酷开系统5.8。安装师傅，服务态度很好，安装比较专业，耐心的教如何使用。京东购物是正确的选择。好评！！！！ 正面 正面
# 电视不错 物超所值 给老妈买的 很满意 操作也简单 画面清晰 正面 正面
# 很好，不错 正面 正面
# 送货速度快，质量有保障，活动价格挺好的。希望用的久，不出问题。 正面 正面
# 帮亲人买应该不错 正面 正面
# 特别好 给爸妈买的 正面 正面
# 已收到货，服务人员服务态度好 好评 正面 正面
# 物流日日顺不错，我地址写错了马上就送到新的地址，雨太大还多次打电话确认时间，虽然快递箱子外面湿了，里面还是好好的，但是快递没有帮忙装支架。电视系统简洁，希望以后能一直升级，电视音质一般，总得来说性价比高，对电视要求不高的可以买。海狮、长须鲸客服服务棒棒哒，不会像其他旗舰问个不停，有什么说什么。 负面 负面
# 疯狂到不睡觉都要抢到它，双11已经错过了，这一次怎样都要买到。哈哈！物流特别赞??????当晚购买，第二天下午就收到货！！从打开箱子那一刻已经迫不及待的想开机了。。一打开，画面非常惊艳，画质很好，无边框确实不错，马上把旧款的创维放到一边去了。。酷开系统挺流畅的，而且可以下载爱奇艺，腾讯等视频软件，音质很响亮，4K屏幕一流。非常好。。。现在还在摸索当中，哈哈。 正面 正面
# 电视价格合理.质量和色彩值得推荐 正面 正面
# 画面不错非常清晰，图案也细腻，主要音效很好像安上音响一般的效果，开机时间长一点 负面 负面
# 电视不错。打了电话以后安装师傅很快上门。 正面 正面
# 电视挺大的，支架就2颗螺丝放不稳，摆电视柜上一碰就摇摇晃晃，猫爬柜子上碰了下电视直接掉地上碎屏了，不退不换，修理费3298元比新买还贵，无语…… 负面 负面
# 　　才几个月，就出现黑屏打不开的情况，有吧友遇到吗 负面 负面
# 物流配送到家 质量很好 价格实惠 正面 正面
# 电视机收到了，49寸的感觉也很大，颜色也好，物流很快，也帮我们搬到家里，安装师傅态度好，很负责，还帮我们连接调试电视节目，教我们选节目，这是第一次在京东买这么贵的电器，以前还不放心。现在放心了！老公也喜欢这电视机 正面 正面
# 送货快，快递员还给试了屏幕才走。还没安装，用后追评。 正面 负面
# 收到货打开试用了一下，画质挺好的，挺喜欢的！！！ 正面 正面
# 电视不错，没有坏点，漏光也基本看不出来，看了下电视剧，有点拖影，网上换个接口就好了，暂时没试。京东的预约客服真的要给差评，没经过我同意擅自把送货时间改到星期五，害送货大哥白跑趟。这里要给送货大哥好评，30几度的天气，大中午把电视扛到5楼 负面 负面
# 性价比高，买来放在出租房使用的 正面 正面
# 电视开机可慢，感觉比电脑还慢，有微鲸电视台，没有直播的电视频道，客服态度很是冷淡，说不能自己安装，必须找他们安装，还必须掏钱，幸亏买的底座版，不用再额外花钱安装了，遥控器拿出来不能用，也没有说明，打微鲸售后电话才解决问题 负面 负面
# 从视觉上不会有那种刺眼不舒服，看多了会头晕目眩的感觉。 最让人方便的还是它最新推出的智能语音遥控功能，它可以根据音色识别，找出相对应的内容，而且可以分辨模糊不清楚的声音，准确度十分高，不会像平常那样大部分的时间都浪费在了按遥控器上，错误率还高，改正也十分不便。 支持的系统也有很多，反正电视机很不错，无论是从质量还是服务还是售后都非常棒！是一次完美的购物体验！ 正面 负面
# 电视比想象中的要大、要好，图像很清晰！ 正面 正面
# 这是第一次在京东买大件电器，结果就是一次糟心的经历。618下单以后，电视第一次两三天倒是给送到了，但是我在家里还没收到的时候，送货人员就给我点了签收的确认，我立马打电话，他说就在我楼下，先点了没事。我说万一通电有问题呢？上来之后打开之后，电视黑屏开不了机，给客服打电话，厂家教了半天各种办法都不好使， 负面 负面
# 以前没听说过微鲸电视，没了解过这个品牌，感觉价格合适就下单了，果然没让我失望，音响挺棒的，屏幕高清，4K看起来很过瘾。 最不满意的是，电视机不是超薄的，还有一点讨厌的是屏幕出现过几次忽明忽暗，不知道怎么回事，如果再出现这种情况，我就报修了，总体给好评 负面 负面
# 价格不行，买贵了 亏大了，系统会有些小bug 负面 负面
# 用了两天，出现了两次黑屏的现象，换一个试试，可以的话再追加评论来 负面 负面
# 货己收到，维修标贴损毁，售后说派人上门，结果被忽悠，感觉还行，没人安装，自己动手，已经在使用了 负面 负面
# 给老家的亲人购买的。 配送速度快，安装人员和快递员都很好。远方的亲人很高兴！ 正面 正面
# 很不错，性价比高 正面 正面
# 画面清晰，音响效果不错，安装要加三百块。。。 正面 正面
# 家里老电视坏了，索性直接换了，风行(FunTV) N39S 这个感觉性价比挺高，上午下单下午就到了，安装好联网一切正常，用一段时间看看，影视资源很多，电影动画片电视剧更新挺快的，满意的一次购物。 正面 正面
# 电视很清 ，反应快，还不错 正面 正面
# 电视很好，比我想象的要大，第一次在网上购买，很满意 正面 正面
# 送货相当快。第二天一早就到了。这个电视机在这个价位还是相当实惠的。系统运行还是比较流畅的。整体的效果还是比较满意的，希望耐用一点，以后不要出问题。打分可以90分。 晒单： 收起 向左转 向右转 正面 正面
# 刚开箱试机，屏幕质地很好，画面清淅度高，功能很全，这个价格很值了！ 正面 正面
# 外观很漂亮 很清晰 无边框感觉很大。 正面 正面
# 活动买的，比在实体店买的便宜 正面 正面
# 师傅上门安装好了，不错。 正面 正面
# 服务态度简直就是一坨屎，我7月28日下单，31号才装好。结果现在8月8号，又送优惠券，又降价，整整少了150多，微鲸客服一句没办法就算了。这样的服务态度简直差到作呕。大家擦亮眼睛看清楚了，这样的服务态度，这样的产品还能走得多远？总之一句话，非常不满意，非常非常不满意！！！！！！！！！！ 负面 负面
# 安装 不求人 电视很棒 关注微鲸很久了 正好家里要换电视 果断出手了 但是有一个小小的bug hdmi接机顶盒 切出去主菜单 再切回来 就显示无信号了 只能重启机顶盒 这有点不方便 希望厂家改进一下 av输出不能显示1080p 画质很渣 这可能跟机顶盒有关 无所谓了 用HDMI就可以了 音效没以前的Sony好 大法还是大法 无可取代 国产品牌还需继续努力呀！ 负面 负面
# 差评！ 先不说东西怎么样吧 一周前收获架子也到了 安装的一直拖拖 好像求着他们似的 直接影响我对微?整体素质评价 简直是受欺负！ 负面 负面
# 这是一款性价比超高的智能网络电视机，又是沪深上市公司兆驰股份正规大厂生产的电视机。京东配送速度很快而且支持开箱通电验货，安装人员也很专业。智能电视机的电视内容是和BesTV合作的，电视内容丰富精彩。很满意！ 正面 正面
# 电视还不错，第一次买这个新牌子，音质一般般，清晰度就不错，支持下国货。 负面 负面
# 挺好的，就是邮费有点贵 负面 负面
# 00），两种方案我都不是很满意。质量画面清晰度其实我说还可以吧，比起大牌还是差点，为什么这么说呢？因为我在家0.5米外看还真有点模糊（没有近视），有点暗。还有你们跟微鲸公司还是两个不同公司，并不是微鲸公司的，应该属于授权，因为我打客服售后他们亲口说的。物流也很差，那天来了也是匆匆忙忙就走了，只是让我赶快检查屏幕，其它都是我自己安装，比起第一次的物流真的很差。 负面 负面
# 挺不错的，家里都很喜欢 正面 正面
# 物流快，这款机子大气超薄就是美中不足有点瑕疵屏不直不完美，叫老板换了一台就好了，要是图象再能亮净点就更好了。 正面 负面
# 画面很满意，就是**员区有的电影看不起，还有的只有5分钟，郁闷。 负面 负面
# 不错啊！画面清楚 正面 正面
# 电视画质非常不错，比双11稍贵了点，不知什么原因连不上wifi。总体非常满意。 正面 负面
# 此用户未及时评价，系统默认好评。 2017-12-25 20:13:54 追加： 小米真心不错，物超所值 正面 正面
# 电视很清晰，安装师傅安装不错。发货速度很快，满意推荐购买 正面 正面
# 价格优惠，质量也好，现在已经装好了 正面 正面
# tv，全金属外壳，外观不错，然而用了不到一天就开始出现黑线，完全失望退掉了。在网上比较再三，因为外形选择了微鲸，收到手的时候感觉塑料感太重，有点失望，但装好了以后感觉非常棒，开机干净，色彩均衡，清晰度明显高于暴风，反应挺快，各种设置也是恰到好处，不愧是专门做互联网电视的。4k片源用的是腾讯视频，片源很丰富。唯一问题是连接歌华机顶盒无信号，继续观察，希望稳定。 负面 负面
# 我买了两个风行电视，本来买给老人用的，因为便宜，但是装好开机以后发现这也太好了吧，性价比很高，屏幕很好色彩很好，尤其是遥控器，特别好，哈哈哈，不错不错，以后还买风行吧，片源好像也很多。专业做电是的品牌真心棒！哈哈 正面 正面
# 照片就不晒了，电视机硬件还可以，但是内容方面简直了，官方应用市场没一个有用的APP，视频内容也是非常少，随便搜个电影bilibili 上早就有了在这里搜还显示没资源呢。电视剧呢，像乡村爱情故事这种必须要钻石会员才能看，赠送的白金 会员根本没用，老哥你也不看看你有几个资源啊？就想让用户买钻石？真是鸡贼的够够的了。综上来说不太满意 负面 负面
# 京东客服商家客服都好！电视有点问题当天反馈第二天就来换新！售后好！打电话就来！京东值得信赖！ 正面 负面
# 外观好看，又便宜，挺值的 正面 正面
# 今天收到礼品了。全是全部到了。暂时各方面还不错。就是送货的让我挺生气。缺点是内存太小了。其它的过一段时间来追加吧。 负面 负面
# 快递员一个人送货 很辛苦 安装人员热情细致 电视也很好 正面 负面
# 试看了一晚，视频资源很给力，但系统不太好，开机太慢，？ 负面 负面
# 用了一段时间，感觉还不错。画质挺清晰的。感觉还算不错吧！ 正面 正面
# 电视也就一般没有说的那么神奇！客服妹妹态度不好半天没人应答！微鲸热线是没人接电话吗？打了半个小时没人接电话～！还好大的那台没买微鲸 不然会被气死～！物流人员态度也不是很好 负面 负面
# 好 挺不错的 很薄不占地方 正面 正面
# 一直想着今年双11入手一台平板电视的线下实体店线上各平台纠结了很久最后机缘巧合选择在京东这里入手到货很快简单安装后就开始欣赏节目了大屏幕真是让人欢喜 正面 正面
# 第二台微鲸，漏光没大家说的那么严重，坏点粗略看了下没有！就是屏幕下方中间有一异物，估计是塑料件的毛刺！影响不大懒的换了！曲面看起来并没有啥特的感觉！还有就是会员略坑，当初199，现在299！还多了个钻石会员！总体满意吧！ 负面 负面
# 值得信赖，音质不错，画质很好 正面 正面
# 完全是电脑小白，之前一直想买60寸，但是发现55寸的确是最有性价比的，于是就吃螃蟹买了微鲸，暂时放在新家未见面，就收货试机一睹真容，感觉还是不错的。听大家说是硬屏，接口丰富方便拓展，感觉自己是买对了。但是，谁能回答我：到底有没有广告？为啥今天来看发现页面上写着内含广告？ 负面 负面
# 电视已收到，还不错吧，妈妈满意 正面 正面
# 微鲸电视很不错，性价比高，速度也挺快，虽然有一个坏点，但不影响观看，就不换了，希望以后都没问题 负面 负面
# 非常好，坏了一台，立马换新的，售后一流！！ 负面 负面
# 虽然蛮后悔错过双十一8000E的活动买了这个，但就电视本身还是很满意的 正面 负面
# 50寸的好大啊，比想象的大好多，遥控器手感很好，操作简单，电视很清晰，超薄的一个人就能安装，送货师傅很好，送上楼来还给调试了，赞一个，比商场便宜很多，超值！ 正面 正面
# 帮朋友买的，三星电视图像清晰，挂在卧室合适。京东自营发货快，晚上拍第二天上午到，真的好快哦！ 正面 正面
# 清晰度蛮好的 广告很烦人 送的会员用处不大 很多剧也是看不了的 负面 负面
# 不错 正面 正面
# 很不错，买的时候觉得大，安上一点也不觉得大。价格比以前贵了，没辙，送货师傅第一时间没找到总开关，差点送回去，真愁人。 负面 负面
# 一般般。这个价位也不会抱太多的期望。比某某TV还是好很多。 负面 负面
# 很满意，不错，物超所值 正面 正面
# 电视不错，清晰，大小刚合适，家人都很满意 正面 正面
# 暂时没发现问题，正常使用，但是在机器顶部有4个黑点，就不退了，不影响使用，但是一个礼拜了到现在挂架还没送给我，不知道啥原因。音响不错，但是大概什么动态的功能后画面变暗了。 负面 负面
# 很满意，还没装呢，物流很快 晒单： 收起 向左转 向右转 正面 正面
# 家人很满意，我也很满意，大品牌质量杠杠的！ 正面 正面
# 用了很久了，现在来评论，除了有点漏光，其他都不错 负面 负面
# 很喜欢小米电现，功能多画质好，还可以手机操作，送货快售后服务好 正面 正面
# 别APP平台，无法播放视频，售后也说不出所以然，就发了几句“我们解码功能强大xxx”广告词，不解决问题。太麻烦了我就不退了，但是以后看到这个牌子都会绕道，也会告诫身边人不要碰这个牌子。 客服像个冷冰冰的机器，对退货流程不熟悉，叫我打客服电话问。我打电话，那边让我到天猫客服问，被踢皮球。说不清楚100元体验费和退货费的区别，说不清楚退货是上门收件还是自己寄件。 负面 负面
# 小米电视机价格不贵，嗯，看着也可以小米的，产品还是可以的，支持小米 正面 正面
# 物流发货很快，收到电视后自己就能安装调试好，画面很清晰，看了几天才来评价的，很超值 正面 正面
# 电视给爸爸买的，总体感觉还不错，就是送的挂架下单说缺货，过两天又有了，感觉亏了一个亿…??，画面感还是可以，日常看电视需求足够，重点语音功能很方便，快进后退再也不用怕一下退过了，送的会员大部分资源都能看，但是299的会员不能看很多美剧，好像要499的才可以，不过我爸也不看，就无所谓了… 负面 负面
# 挺好的，看久了下面底部很热，售后安装220元，被兜售一个HIDMI高清线99元，还有58元的有线电视线，一共花了快400块钱，有点被售后忽悠了，后来网上一看两根线最多40快！线上给你优惠，线下想法搞你！ 负面 负面
# 看上了 画面清晰 流畅 服务也很好 买了很久才申请的壁挂 服务好 很满意 正面 正面
# 的.之前选电视选了好久看得头疼,小米是很坑的幸亏没买,选来选去还是微鲸吧,配置需要的都有了,价格也在预算里,售后貌似也不错有1年换新政策呢,第一次买这个牌子电视 真心有点忐忑,京东方的硬屏参数还是不给力啊色域只有68%呢,实际看起来也就这样吧,也许是机顶盒不给力没有高清信号效果也就那样了,会员现在还没领取 因为还没搬家过去,等到时候在开通了仔细体验后在感受吧 负面 负面
# 服务好，质量也不错，就是安装费用太贵，后来自己安装就花7块钱，总体ok 负面 负面
# 东西不错，屏幕看上去蛮清晰，比乐视要快些，就是内存太小不够用。 负面 正面
# 这个最重要的显示屏不很好，是京东方的，没仔细看，大意了！！！去年50寸的还可以。缺点： 1、图像不是很清晰； 2、音箱系统音质太差； 3、播放影片时不时有卡顿。 4、商家说的纤薄机身仅仅只是一条边框，电视机根本不纤薄！ 别的目前还行。 负面 负面
# 东西挺好的，还实惠，就是在挂的时候遇到点问题，物流也挺快的 正面 正面
# 不错 挺好的 就是比去年涨价不少 大趋势没办法 下次要买还会来的 负面 负面
# 很轻 感觉 挺单薄 不过价格也便宜 对得起 这个价格了 正面 正面
# 第二次购买微鲸电视了，第一次去年给爸妈买，还是原装LG屏幕，用了一年，蓝牙遥控，语音功能，系统都非常好用，喇叭声音音量和音质都比一般电视强，今年虽然涨价了但是通过比较和一年的体验还是下单了微鲸，试了两次还是满意的。 负面 负面
# 物流很快，有事没有装，昨天刚装好，看一晚上，真的很给力的一款电视，简洁方便的菜单，功能齐全还唱了首歌！没有选错。 正面 正面
# 电视不错，没有坏点，漏光也基本看不出来，看了下电视剧，有点拖影，网上换个接口就好了，暂时没试。京东的预约客服真的要给差评，没经过我同意擅自把送货时间改到星期五，害送货大哥白跑趟。这里要给送货大哥好评，30几度的天气，大中午把电视扛到5楼 负面 负面
# 这个心情真是无语了，还没开始用就又搞活动降价150元，真想退货。这叫消费者怎么树立品牌忠诚度，真是！ 负面 负面
# 送货速度很快，服务很好！电视送给爸妈，很喜欢！京东值得信赖！还犹豫的朋友们赶快下单吧！ 正面 正面
# 中肯的说整体上还是对得起这个价格的，但音效和画质都很一般，尤其是音效很是失望，不能用来听音乐，音质很杂，不知道是不是都是这样的? 负面 负面
# 送货快，但是再打微鲸电视安装热线时候，热线服务生直接给你说，要用微鲸自己挂架，如果因为挂架出了问题他们不管。弄得心里不舒服。还没用他家电视就在扯皮。感觉不好。 负面 负面
# 屏幕出厂带有一层塑料薄膜要撕开才能看清楚，屏幕清晰度相当高，看超清格式的视频就足够清晰了，这点倒是挺满意的，据我感官屏幕应该只有72色域，相对更高色域的屏幕稍显发白，不过这价也不好要求太多。系统流畅度不错，按着安卓手机的尿性买之前还以为这配置会卡得很呢，看来安卓电视和手机还是有差别的。总的来说，这机子物美价廉吧，就看能用多久了。 晒单： 收起 向左转 向右转 正面 正面
# 暂时没发现问题，正常使用，但是在机器顶部有4个黑点，就不退了，不影响使用，但是一个礼拜了到现在挂架还没送给我，不知道啥原因。音响不错，但是大概什么动态的功能后画面变暗了。 负面 负面
# 非常不错的一款电视，三星4k黑晶屏！系统操作流畅BES电视节目提供商，节目资源应有尽有，什么电影，少儿，体育通通不在话下。最令我满意的是声音感觉很震撼。三八久久买的，分了一二期。总体很满意，不过就是安装费要了我一百武，说好的免费安装却要钱，实在不太爽。还好电视没问题。先用用看吧，以后再追评。 正面 负面
# 不错刚开始觉得颜色不好，有点失真。后来发现人机对话功能不错。就是没有售后安装服务这点不太好 负面 负面
# 显示效果非常好接硬盘播放流畅清晰音效不错，这是第二台了价格比去年贵了，值得推荐。 负面 正面
# 电视整体还是满意，说说不满意的地方，1电视开机系统准备太频繁，时间两分钟左右，感觉很窝心，2习惯了使用机顶盒遥控器，此电视遥控器不能被学习，如果看机顶盒直播节目就得用两个遥控器，很不方便。其他因为才使用还没发现。 负面 负面
# 饥饿营销，永远都是抢购的节奏，性价比还是挺高的，至于质量只有用过的才知道！ 正面 负面
# 给家里人买的，现在电视都涨价了 负面 负面
# 第一次在京东购买电器，8号下单，9号就收到货了，电视画面清晰，棒棒的，安装师付很热情，服务周全。五分好评 正面 正面
# 货了，安装也很快，暂时没发现什么毛病，音效确实不错，不愧是李健创立的品牌，性价比高，操作也简洁方便，速度也挺快的，各方面还有待考证，就是自带的安卓看电影电视很卡，老是在缓冲中，另下的就不会。还有屏幕漏光挺厉害的，透光也是，做工还有带加强，不是全金属外壳，还有要求会员的片太多，不是会员几乎看不了什么东西，你们的会员并没有这么值钱，建议买微鲸电视送永久会员！！！ 负面 负面
# 电视性价比还是挺高的，用起来也挺方便。 正面 正面
# 第一次买微鲸电视，看到性价比特别高，所以就入手了一台，果然物超所值，开机特别快，资源也挺丰富的，而且是硬屏4K分辨率，清晰度和色彩都不错，蓝牙遥控器是一个亮点，但是这电视的边框是塑料的，看上去质感不行，比较廉价，不过这个价位可以理解，希望微鲸电视质量也过硬。 负面 负面
# 双十一yiqianba买的，刚刚装上，安装师傅。。挺好的。加上挂墙支架，一共收了140，还帮忙开通了奇异果会员， 正面 负面
# 第一次在京东买电器，服务比实体好太多，安装的师傅服务很好，全满分，下次再来 正面 正面
# 大屏还是狠舒服的，颜色也不错，没有4k资源，不知道效果怎么样 负面 负面
# 之前买过一台，都有配蓝牙遥控器，这次没有。再说了，和女朋友买的同款电视，她晒单有蓝牙遥控器和猫超卡，而我只有蓝牙遥控器，这样的商家我选择给差评，以后也不会再买了 负面 负面
# 虽然用了半个多月才送来，但是终于寄来了，性价比算高的了，画面有待提高 正面 负面
# 真心不怎么样，用的联通的智慧沃家，看电视画面渣渣的。会员专区里面的还可以，问题是家人一般看直播比较多。评论没错，屏幕边缘按一下就往里面凹进去的感觉，没什么质感。2288买的，也算了吧。希望大家还是买别的品牌吧，毕竟术业有专攻，感觉前期都是靠低价攻占市场，收获这么多好评。现在涨价这么多，品质反而下降？ 负面 负面
# 产品本身什么都满意，就是有几点：1.开机贼慢 2.内置应用商店的应用少的可怜 3.影视资源也不算多 4.遥控器比较寒碜都没有带滑滚 5.厂家的客服不咋地，一个互联网企业问点小问题都不专业怎么立足！ 负面 负面
# 还不错，挺好 正面 正面
# 今天收到的物品，东西外观很惊艳，电视比我想象的大！清晰度很好！没感觉有色差之类的，现在家里面的网络还没弄好！看卫视节目还不能看，这款电视比我现在家的电视好很多！对了，送货很快。表扬下。支持国货支持风行???? 正面 正面
# 这个电视很还错，价钱便宜值得一买 正面 正面
# 屏幕还不错，感觉音响一般，声音都开到20了，金色边框感觉粘上去的贴合不够紧，还没连网络，以后再来评价内容 负面 负面
# 第一次买创维电视，在58寸和65寸之间犹豫了很久，最后还是选择了65寸，本来担心会太大，装上后效果不错，12号买的，需要调货的原因等了几天15号送到，货到20分钟后安装师傅就来了，创维提供的免费安装，加了点钱换了个好点的挂架，提醒大家要等正规的创维安装人员，物流信息会泄漏，货没到就有其他安装人员电话联系要安装，但要收费，差点被忽悠 正面 负面
# 最差的一次购物，电视机清晰度很差，而且售后和物流也不行。最不满意的就是他们的物流，找物流公司之前不能先网上百度一下信用吗？网上一片说他们家物流差的声音。而且明明没有到我的收货地，也没打电话，说是联系我才没有配送。物流图能说明一切。申请退款还不给退。 负面 负面
# 刚开机看了，看起来很不错，没有坏点，现在55寸电视也是微鲸最便宜了，而且也很好用，就是没有hdmi线，会员很坑，员299，钻石会员要499 负面 负面
# 非常满意 正面 正面
# 画面清晰，流畅度一般，用了一个多。没发现质量问题 正面 负面
# 很不错啊真的很满意，很不错。。 正面 正面
# 电视虽然是抢到的 但是看着屏幕不行 太花了清晰度不行 价格也低 凑合看吧 负面 负面
# 很不错的商品，可以升级的模块，大尺寸电视 晒单： 收起 向左转 向右转 2017-12-11 21:56:20 追加： 什么鬼，假4k，坑die呢 收起 向左转 向右转 正面 正面
# 清晰度不错 音效比一般的电视要好些,色彩有些颜色偏蓝 其他的都好.送货稍慢比京东预计的时间晚一天. 负面 负面
# 宝贝确实不错，比我以前买的其它牌子还要好的多，一点都不卡，唯一安装费太贵。 负面 负面
# 物流太慢! 负面 负面
# 还是选择了微鲸，总体很满意：一：同等价位的电视这个硬件配置绝对最具性价比，买电视还送了壁挂架子。2G运存加16G存储足够用了；还有两个usb3.0接口比较给力 二：系统使用起来简单易用，开机没有广告。不限制应用安装。 三：蓝牙语音遥控器使用方便，不用对着电视就可以轻松操控。在电视设置里面还可以看到遥控器电量。 最后个人感觉接口再提供一个SD卡插槽就更完美了。 负面 负面
# 客服态度差，产品描述不清楚 负面 负面
# 给父母买的电视 爸妈很满意 正面 正面
# 电视不错，物流快，服务态度好，屏幕效果好，音质一般，遥控器手感不错，对客服巨头鲸的服务很满意。 负面 负面
# 好，一次不错的选择，非常清楚，非常好。 正面 正面
# 电视机不错，双十一的价格也不错，但安装师傅的收费与网页上的价格不同，送货、安装是同一个人，不清楚是谁的问题，最后电视机是自己安装的。 正面 负面
# 很不错的电视，嗯质感很好，送货也很快。 正面 正面
# 电视 目前没问题，问题是买来没几天就降价，心里就不舒服了，搞活动都是套路啊……降价太快了，几天一降价…… 负面 负面
# 别APP平台，无法播放视频，售后也说不出所以然，就发了几句“我们解码功能强大xxx”广告词，不解决问题。太麻烦了我就不退了，但是以后看到这个牌子都会绕道，也会告诫身边人不要碰这个牌子。 客服像个冷冰冰的机器，对退货流程不熟悉，叫我打客服电话问。我打电话，那边让我到天猫客服问，被踢皮球。说不清楚100元体验费和退货费的区别，说不清楚退货是上门收件还是自己寄件。 负面 负面
# 一直在用创维，从老式电视就用它了，毕竟是老牌子。值得信赖。买回来家人都喜欢。 正面 正面
# 幕质量一般，只能说勉强对得起这个价格，整体做工还需要改进。 资源上，基本上都是腾讯的，并不丰富！经常感觉还是切换到机顶盒看联通iptv好了！ 软件上出现一次进去点播时突然黑屏问题，长时间都不能恢复，也没有反应，只能断电重启。 ps今天发现u盘识别问题，插着U盘开机后，发现插拔后再也不能识别U盘！ 再说说物流吧，日日顺物流是非常快的，验货时配送师傅都比较着急。 负面 负面
# 不错，跟描述的一样，很好用也很给力 正面 正面
# 有点小划痕，不影响使用就懒得换了，其他的满意。。。希望质量好能多用几年。。？ 负面 负面
# 这次买了两台，去年买了一台，效果很不错，不用机顶盒，简洁多了，就是会员太贵…… 负面 负面
# 买来做显示器用的，调试一下后能用，分辨率低就地点吧 负面 负面
# 非常棒！很好，这次的电视很好没什么毛病。京东的售后服务还是很给力的！ 正面 正面
# 第二次购买了，相当不错的电视。很喜欢…… 正面 正面
# 电视真的很棒！，画面音质都很满意，那个叫什么何先生快递员也很负责人，虽然只是负责送货，但是我不懂怎么使用，他会很耐心给我讲解，很乐意耐心地为我解答，比小米客服棒多了，小米客服一句话就叫我换，不负责任！不多说，五颗星！ 正面 负面
# 电视到了，屏幕真的很清晰，送货小哥也不错，秉承京东规定吧，让坐也不坐，图片是用屏幕大师测试的，很好，没有坏点，反应灵敏，看差评说开机时间太长，我试了一下，只是在断电重启会长一些，这属于正常，没有开机广告hin好，就是送的挂架太少了，没赶上。。。 负面 负面
# 喜欢的网络动画不用开电脑看了。会员可以用蓝光品质播放，细节很到位，这个需要自己设置，它默认的是高清。 2.说下建议 因为是大屏高分，所以部分第三方手机应用闪退不支持，比如慕课网，哔哩哔哩等。还有一个就是屏幕封装有点缝隙。这几个希望改进。期待新系统的推送。 3.对了，什么当贝市场呀，自己装一下，还有HDP不错。 想看高清还是装个数字电视机顶盒吧，网一卡真的跪了 负面 负面
# 电视和描述的一样，画质比较清楚。就是遥控器与电视连接蓝牙的时候费了不少周折，还好，都是小插曲。弱弱的问一句，你们的遥控器和电视连接蓝牙的时候好连接么？希望以后能一切顺心！后期我再追评哈！ 负面 负面
# 画质清晰细腻，颜色靓丽，物有所值。送货速度快，服务很周到。 正面 正面
# 好给力！颜色鲜明，值得买！ 正面 正面
# 质量好，画质清晰，不错 正面 正面
# 给父母买的，开始一万个不同意，说家里电视多，但是都是老款的大屁股电视，还小。先斩后奏买回家，都觉得挺好的。 正面 正面
# 材质很一般，轻飘飘的，不结实 负面 负面
# 也有买过的，我是2988买的，买贵了。5.1价格现在价格一个月掉了100多还送东西。这个还会掉。望买的用户考虑一下。这个最先是卖2499元的。价格不地道。。。。。启动慢，，，十几天了，，每次开机4-5分钟左右。。。联系客服说是升级，我是最新版本了，不知道还怎么升，，，如果买这个电视，开机可以先开洗完澡再看，，，慢，，内存也不足。，，，反正一个字不值当的东西。 负面 负面
# 电视还可以，关注微鲸很久了，价格迟迟下不来，等不了了，音效可以，不过这个语音遥控有点鸡肋，功能太少，基本只能换个声什么的。 负面 负面
# 质量不错没弯曲也没漏光，就是片源不支持4k 负面 负面
# 第三次买微鲸电视了，虽然比上一年价格贵了一些，但是同比的价格还是比较实惠的，我们把它作为教学的使用，互联网电视的优势还是相当大的。 负面 负面
# 不错，效果挺好，音质也不错，操作简单，就是听说遥控器愿意坏，我同事家的遥控器就坏了，不过店家同意免费调换，客服挺热情，就是总是有上句没下句。 负面 负面
# 自营购物体验非常好，送货快！ 正面 正面
# 安装 不求人 电视很棒 关注微鲸很久了 正好家里要换电视 果断出手了 但是有一个小小的bug hdmi接机顶盒 切出去主菜单 再切回来 就显示无信号了 只能重启机顶盒 这有点不方便 希望厂家改进一下 av输出不能显示1080p 画质很渣 这可能跟机顶盒有关 无所谓了 用HDMI就可以了 音效没以前的Sony好 大法还是大法 无可取代 国产品牌还需继续努力呀！ 负面 负面
# 对微鲸有些失望，画质没有想象的好，会员也看不了啥 负面 负面
# 运行速度挺快的，价格绝对合适，物流运送也不错，因为是乡下还给送到家，但是安装居然收费30元，我们是在盒子里拿出来，插电联网就安装完了，不用挂壁的。整体不错 正面 正面
# 整体效果不错 正面 正面
# 画面非常清晰，音质感也很好，外观看着挺大器的，总之收到宝贝很开心称得上是物美价廉 正面 正面
# 使用了两周，效果不错 正面 正面
# 之间犹豫了一下，相同配置，到手后发现金色非常大气上档次，有一点要提就是买电视不仅仅是买配置了，节目资源的整合也是挑选电视的50%，而资源内容方面了解之后微鲸做的还是很不错的，然后就根据空间情况选购。总之这次购物体验还是不错的。一开始物流配送发错了货，折腾了两天，昨晚收货，接电开机注册成功，今天看了一下，暂时没遇到的问题。就电视本身来说我还是比较喜欢的。好评！ 负面 负面
# 为什么电视机声音一会大一会小，屏幕颜色不够鲜艳，有点暗，郁闷，上京东第一买就这样 负面 负面
# 还行，但技术比较差，市场应用程序太少，且大多数不实用！！！手机投屏总是连不上！！！ 负面 负面
# 电视质量一般，看电视有点卡了 负面 负面
# 微鲸电视黑屏，售后各种服务态度差，官方微博居然拉黑我？这就是你的员工？@微鲸 @微鲸客服 @李怀宇 你的员工素质真的差。 负面 负面
# 宝贝很好！海尔售后服务态度一流的棒！信赖京东，信赖国产大品牌！买电器上京东！ 正面 正面
# 雙12下的單，今天上午就送到了。電視已安裝好，清晰度還不錯。長虹電視，值得信賴！ 正面 正面
# 卡，慢，死机，闪退 负面 负面
# 不错！TCL国货老牌子，值得信赖！??? 正面 正面
#  系统启动速度比想像中快多了，开机后画面颜色很鲜艳，音响效果也不错，开机就连网把系统更新了，不知道为什么要更新两次，系统操作比较流畅，操作得快的情况下偶尔会有卡顿。遥控器手感很好。 电视wifi是不能关闭的，其实完全可以象手机一样做个wifi开关功能并不难吧，用机顶盒的时候完全没必要开着wifi一直搜索信号，又费电又影响wifi模块寿命，希望这条厂家能看到。 负面 负面
# 用了两天，界面交互性很好。 送了微鲸一年会员。 和腾讯合作有一些片源。 自己可以安装很多应用。 可以看英超了。 唯一的问题：有时候看蓝光会卡，可能是电视的WIFI模块适配有问题 负面 负面
# 不错哟 正面 正面
# 很好，质量不错，图像清晰。很不错！！ 正面 正面
# 电视是寄给我爸妈用的，我没看到。但是老妈说音响有点差。快递小哥人不错 负面 负面
# 开箱就有质量问题，办理退货程序超级复杂，售后超级的烂，天猫旗舰店客服服务也超级的差，以后不会在购买微鲸的产品了，服务差，虾米客服服务最差，问问题不吭声，不回答 负面 负面
# 再加上这家店是代销店，价格补差都补不了的，大家记得看好官方店再购买。 赠送的遥控器和挂架，也是要催了才给发的。不去催，它就不给登记，不登记就不会发的。 申请售后，说重新拍也被拒绝了，这次就算倒霉了，两台电视损失了1000元，以后再也不会买微鲸的东西了，微信朋友圈上也跟大家讲讲这个品牌的事迹，和极差的市场运作。 体验极差，以后再也不会买微鲸的东西了。服务不好。 负面 负面
# 小米电视，新国货，给力，屏大，性价比高，双十一抢的，货源紧缺，一九九九应该很实惠了 正面 正面
# 价格便宜，就是开机有强制广告，看着效果还算不错。 正面 负面
# 没有广告，只是稍微等个十多秒 负面 负面
# 画质不太好，亮度不够，对比度不高，像是杂牌货。 负面 负面
# 小米电视图像很清晰，功能很强大操作也很方便 正面 正面
# 昨晚下的单，今天就到了！唯一有点不满意的是安装还得预约微鲸客服，就不知道什么时候过来安装了。 负面 负面
# 我觉得这是一款，性价比非常高的32寸电视，根据它的配置，外观，颜值，使用率，反应速度，都非常非常满意，而且价格不高，比传统品牌，要好，有好处不少，只是行动，支持京东，支持京东快递 正面 正面
# 感觉很好，性价比很高。 晒单： 收起 向左转 向右转 正面 正面
# .看球时画面比较清楚，有轻微托影(小遗憾，毕竟我看电视主演就是体育)，体育资源不是狠丰富(我没找到西甲,有点吹毛求疵了，还不知道其它能不能看直播)。总体感觉：因为我对电视的要求不高，主演看球，一天体验，感觉还是买到了自己想要的电视,这个价位来说比较值。微鲸作为年轻的互联网电视来说是比较用心的，一些小细节希望还需努力用心！最后要说京东物流，转天上午送达，给力！ 负面 负面
# 原来的坏了换新的 负面 负面
# 物流及配送师傅比京东服务好，帮我安装好底座通电试完无问题才走。电视接机顶盒很清晰，比小米4A强;网络视频也很清晰，看蓝光无压力。不足之处：很多热门视频要SVIP才能看，语音比小米差得不是一个档次。另外1元预约赠送的挂架会员之类不知什么时候到货。 负面 负面
# 电视很不错。物流也很快，目前还没有好的4k片源，所以目前来说还是不错的。 负面 正面
# 风行电视很漂亮也很超值，这个价位还送会员买到就是赚到，物超所值！快来抢购啊，清晰度没问题大家不要质疑，正在用没发现问题，售后和客服加上买的不担心。妥妥用不怕用坏。会推荐别人来买的。我已经是风迷了。 晒单： 收起 向左转 向右转 正面 正面
# 老品牌，我信任，看着不错啊。 正面 正面
# 爸妈超级喜欢，迫不及待的安装上了，清晰度好美观大方，客服更没的说，商家刚发出货，我这边就按错了，确认收货了，很担心的，怕收不到货，客服一路给我发货物已到什么地方，不必担心，信誉一级棒， 正面 正面
# 宝贝送到了，物流很快，给力！ 正面 正面
# 电视机不咋地，画质、音色都不好，服务态度也很差。 电视买了能有20天了，到现在发票还没给我开出来，说是财务统一开发票，一问就是正在沟通中，请耐心等待。不知道要我等到什么时候，需要买电视机的朋友，不要轻易相信这家店，购买别的牌子好了，有种被欺骗的感觉。 负面 负面
# 一直观注风行电视，真的是性价比超高的电视呢，不仅外观精致，而且屏幕清晰运行流畅，电影片源也比较新，覆盖了所有热门的电视剧和电影，小宝喜欢的动画片也很全，还有美食和养生的节目，真的非常棒，风行真的值得推荐，实物比图片还要漂亮，送货速度也很快，上门安装我很满意，售后服务一流，非常棒的卖家谢谢 正面 正面
# 送货员，非常给力，一直等到调试好才走 正面 正面
# 图像不清楚没有用几天就坏了 送货慢的老火 负面 负面
# 最垃圾的电视，无线网络经常链接不上，我家网络完全正常，其他电视或者手机电脑的wifi无线链接一直正常，售后垃圾，安装师傅软件安装一半承诺第二天来继续安装，之后就没来了，客服售后的解决是 ：也没办法联系他们当地这些零零碎碎工程师 负面 负面
# 试看了几天，感觉没有想像的那么好，微鲸会员的资源太少了，画面还算清晰，物流很快，总体感觉没有达到心里的预期，语音搜索有限，不知道能用几年， 负面 负面
# 刚收到货，看着很不错，用一段时间再来追评 正面 正面
# 一般吧，太厚了，架子也够厚，无线连接老是断 负面 负面
# 买的第一台微鲸电视 感觉很不错 系统很流畅 清晰度也可以 就是个人感觉遥控的时候会有短暂的延迟 外观各方面还是感觉挺好的 这个价位性价比还可以 负面 负面
# 物流快，电视不错，其中一个遥控器语音不行 负面 负面
# 台电视时的客服都是抢着回答问题和服务的，可是还没到两年，好像微鲸的初心变了，每次和客服交流对话都是和像机器人一样死板。做为客服无法为客户带来好的体验，这是作为客服的悲哀。但是微鲸的电视质量还是有保证的，拿了那么多台电视机，就只是坏个了摇控，画质和色彩也还行。就是现在涨价涨的厉害。再一个是二代的电视的脚比一代的不方便。最后祝微鲸越来越好，成长的同时别忘了初心。 负面 负面
# 在618选择了微鲸。首先，京东发货确实挺快的，但是送货有点恶心，差评。其次，送货不影响电视机的质量，拿到当晚就试了机子，投屏，华数，下载keep健身APP，会员看电影，都很流畅，开机速度确实有点慢……只能归结于智能机吧。而那些杜比4k什么的还没那种特殊要求，平时看看电视电影已经足够了……618活动也很划算。最后希望会员可以看更多电视电影咯，机子持续好下去咯。 负面 负面
# 基本上就是噱头，没有宣传中的那么好，基本没有任何改善，黑暗背景下四角全是白光，这应该就是传说中的漏光吧，omg。再就是背部的散热口，播放半个小时后能够明显感觉到很烫，很烫。再就是遥控器，缩水了，虽说评论后可以得到语音遥控器，可毕竟是迟来的爱啊。作为一个微鲸的老用户，冲着是对之前产品的良好体验才来再次购买的，而赤裸裸地标注是品牌高端系列，带来的体验确不敢恭维。 负面 负面
# 然发现了微鲸。对比了下，比小米乐视性价比高，硬件配置更高，原来买过kktv，但是对比后发现微鲸更好性价比高，虽然价格贵了一点点，但是得到了更强的硬件，所以果断选择，在618期间果断下单。很快到货，拆开后很惊艳很漂亮，挂到墙上高端大气上档次，开机流畅，遥控操作方便，UI很方便，画面细腻颜色鲜艳，总之一切到目前都很满意，大大的赞一个，推荐想换只能电视的朋友购买。 负面 负面
# 开机需要5分钟以上，致电客服，说系统需要更新3～5次，什么系统一次更新不了吗？为什么上门安装的师傅没有告知？ 负面 负面
# 非常好，非常喜欢，有没有会员，送我们一个 正面 正面
# 一开始对商品抱以极大希望，但是物流速度实在不敢恭维，说七天到就七天到太守诚信！商品暂且不说，我只想说这物流，这速度，也没谁了。就这物流速度，能回头的顾客不敢相信能有几个！给物流差评。 负面 负面
# 电视造型还可以 其他的就是渣渣 贪便宜 吃大亏 要买还是买老品牌啊 这电视的画质我是服了 垃圾中的战斗机 关键是 反应慢 死机让人受不了 这就是质量不过关 每次都要关机重启 准备下手的小伙伴 慎重啊 不要再被忽悠了 千万不要贪便宜 负面 负面
# 感觉还是不错的！我最喜欢红色边，和音响，但总得来说比想象的小，当初应该买65得了！很不错！用着看，不知道售后如何，只有出了问题才知道，退款还未收到 正面 正面
# 一分都不想给，京东这次让我太失望了，买的电视没有声音，说是退货上门取件，规定好的时间不去，一直拖着，联系客服，客服也不回应，千万不要相信京东自营，说的特别好，做起事来，你就知道了，这次真是太失望了！ 负面 负面
# 物美价廉 正面 正面
# 刚装好，开始用，很多节目都要买会员。小米官方旗舰店说送儿童会员月卡，不知道有没有？ 正面 负面
# 京东家电正品低价服务到家 正面 正面
# 货物送到，物流非常快，非常好。 正面 正面
# 很喜欢的一款电视，画质清晰，音质优秀，胜价比跟同尺寸的绝对无敌。 正面 正面
# 鬼迷心跳买了微鲸这个破电视。质量非常差，刚买就内屏爆裂了，开机特别慢，wifi超级不稳定。宣传讲的一年内只换不修全是骗人的。上当后才了解到微鲸电视是TCL代工生产的，上门来我家处理的售后是委托海信电视的，完全没有保障，彻底是一家垃圾公司。大家可以上网查一下，无论电视机质量还是售后评论查的贴子比比皆是。这是本人真实的教训，大家千万不要买。 负面 负面
# 电视不错不错 正面 正面
# 这价钱超值，收到货马上装上看了一下。很清晰式样也蛮好！赞赞…… 正面 正面
# 送货快，界面清楚晰，超窄边框，功能齐全，家人都喜欢 正面 正面
# 帮朋友买的，非常好我看着都眼馋感觉还不错我都有点儿后悔当初没给我们家买了。朋友是赞不绝口啊边框窄到几乎没有看着都非常美观大气上档次高大上，价格还不贵物美价廉微鲸这个新生的品牌儿。看起来样子真的不错系统体验应该也不错，毕竟是腾讯的资源和合作的只不过安装的有点儿多事儿。在我朋友家人面前有点儿多嘴多舌的。 负面 负面
# 没有想像的好，画质一般，音色也一般般。 负面 负面
# 性价比最高55寸之一，值得入手。发货速度迅速。脚架安装很方便。开机直接升级了系统，开机时间稍长，没发现有恼人的开机广告。AV端口设计是个亮点。机身有光纤输出，有回音壁的同学耳朵可以享福啦。 负面 负面
# 分辨率太差了，远处都看不清。 负面 负面
# 物流快，价格低廉，适合老百姓，信赖，支持！ 正面 正面
# 画质真的好 音质也可以 正面 正面
# 电视机质量不怎么样，一个55寸的半年不到屏幕坏了，之后换了一个新的又出现网络连接不上的问题，每次都得回复出厂设置才行，建议大家买之前考虑好。 负面 负面
# 电视不错，清晰度音色色彩度都很好，值得拥有，夏普值得信赖，好品牌就是好 正面 正面
# 安装及时到位 正面 正面
# 这个电视真是买值了，遥控反应特别快，看4K电影特别流畅，领了免费的两年会员后，基本上影院刚下架的热门电影都能看，开4K后有种电影院看电影的感觉。但是这垃圾快递我就不想说了，省内发货，第一天下订单，第四天才到，这种距离我骑自行车都能这个时间赶到，感觉就好像在故意拖延时间，比方说上午7点半到达信阳，下午20点半才从信阳出仓，莫名其妙 负面 负面
# 电视机不咋地，画质、音色都不好，服务态度也很差。 电视买了能有20天了，到现在发票还没给我开出来，说是财务统一开发票，一问就是正在沟通中，请耐心等待。不知道要我等到什么时候，需要买电视机的朋友，不要轻易相信这家店，购买别的牌子好了，有种被欺骗的感觉。 负面 负面
# 感谢京东这次换货十分顺利，双11买的货当时没有仔细验货，年前开箱，发现箱子破损，然后里面的屏幕碎掉，立马给京东打电话处理。相信京东，没有错 负面 正面
# 好评，物流很快显示18号收到货，17号早上送到，安装人员安装，师傅特别热心热情，拿回来之后感觉惊呆了！电视屏幕超大，65寸的非常惊艳，打开电视机感觉屏幕十分清晰，而且最主要的是电视非常便宜，价格实惠，这个价格能买到65寸的电视非常惊喜，期待风行电视越做越好！！ 正面 正面
# 画面挺清晰的，该有的功能都有了，而且是高配，就是声音有点失望，相比5年前买的sony差不是一点.支持国产，仍需努力. 负面 负面
# 除了开机慢、电影资源少且港片无粤语版外，其它还可以，性价比较高 负面 负面
# 东西很棒超值 正面 正面
# 米，面板不详，内存2G，8GROM，还有广告，算了。 只有微鲸，明确了2G内存16G ROM，IPS面板（大概是国产吧，稍微遗憾）。于是果断下单了。 收到商品，第一，系统流畅，不卡，和同样2G 内存的乐视S50 AIR一个天一个地，赞。第二，屏幕，无坏点，赞。第三，亮度均匀性差一点，这个有点遗憾。第四，片源很不错，比乐视这个搞笑的片源越来越少的强几百倍，赞。 负面 负面
# 了一下，网上评论还不错而且测评表现比同配置的要好价格也不贵，正好818有活动于是直接下单，19号中午收到开机试过正常，做工中规中矩，图像画质不错开机较快会员注册使用方便，唯独喇叭音效输出实在太不理想看来要接外接音箱。因为没买挂架暂时放电视柜上使用。看了一下背面挂架尺寸为20*20，背面接口在侧面接各种数据线还是比较方便的。先写这些，过段时间看看效果再来评价。 负面 负面
# C,相当良心，所以还是选了创维。四、电视也今年5月份刚上市，虽说对电视没有多大了解，都是网上查看，电视用的cpu也是去年新出（至于好坏我也不懂，看了很多，大家可以自己查看）五、对供应商客服很满意，纠结了好几天，有什么问题都问到供应商客服，而且每次都是耐心及时给回答，对于这点体验很好，相信售后也很给力的。安装也相当给力，当天下午到货，晚上就装上了，还免安装费。 正面 正面
# 垃圾中的战斗机，新机到手，通电后，闪一下就开不了机了 负面 负面
# 55寸电视看起来就挺大的，看自带的软件节目挺清晰，第一次开机有点慢，以后都用遥控器开关机还是挺快，第一次用智能电视，家人都说挺好的，5分好评。 负面 负面
# ，也联系客服要了微鲸送的挂机。微鲸电视在产品本身、客服、运输安装上都很不错，为什么非要在一个小小的挂架上做这样的文章呢？让人感觉不是很舒服，其实完全可以一百分的用户体验，这样只能给到95分。我宁可商家没有这个赠送挂架的活动，我会自己选择花钱购买！！！！！！！！！！！不知道其他用户有没有这样的感觉！这算是细节吗？？你想要让大众接受一个新的品牌这样应该有问题吧！ 负面 负面
# 电视整体不错，送会员、礼包，性价比挺高。画质清晰，整体厚度也挺薄，就是屏幕与边缘的缝隙比较宽，宽的我都无力吐槽了。看了一段时间，期间出现过俩次遥控器突然失灵，最后重启电视恢复，不清楚怎么回事，咨询客服让恢复出厂设置，恢复后暂时没有失灵过。我想应该是系统问题，望以后优化。客服回答问题及时，虽然专业问题回答的不够专业，但服务态度挺好。 负面 负面
# 家里买的第二台微鲸电视了，一如既往的好用，资源也是够多的，对比了乐视小米，最终还是选择了熟悉的微鲸，赶着618活动价赶紧入手，就是12号0点十几分下的单，说挂架送完了，白天我再看了一下又有送挂架。我就郁闷了。 负面 负面
# 屏幕严重漏光 换货故意推迟 故意推脱时间不发货，大家购买慎重 负面 负面
# 鲸的，我买电视的准则是在能使用的基础上考虑性价比。虽然不是很懂，但对比了一些硬件参数，再加上做活动，以试试心态下单了。 现在使用过了一段时间，感觉画面还行，卡顿也不明显，作为电视的功能是能胜任的。至于安装app就没怎么用了。顺便提一句，图里面IPTV那个界面提示升级是指机顶盒，开始没搞明白以为是要升级电视的操作系统，搞得拿电视的蓝牙遥控器狂按没反应， 汗一个 负面 负面
# 电视挺好的，暂时没什么问题，反应有点慢，内存加1g就完美了 负面 负面
# 看来一阵，说说感觉，4K感觉很清晰，资源的话如果装个小鹰直播 再来个爱奇艺会员，那基本上啥都有了。不足的地方就是漏光很严重，看电影的话 上下两条黑边很明显的发亮。喇叭质量太一般，接个小音箱后感觉好多了。目前就这么多，其他如果有特别的会追评。 负面 负面
# 老板抠死了，连个挂架也不送，买完搞活动送挂架，买时也不说要搞活动，啃爹呀，坑爹，这个43的4K清晰度不如之前的50A的而且亮度也不行，偏暗，侧面看厚，总之这次购买不如上次，相差半年多，价格也涨了不少，可能是品牌知名度高了，行大欺客呀！ 负面 负面
# 送货很快，师傅来了就按照我们的要求直接把电视挂墙上了，非常好！ 正面 正面
# 很好，很清晰，显示屏很大 正面 正面
# 双十二买的发到乡镇 没想到这么快就收货安装了 安装师傅很专业 讲解很细致。电视外观漂亮 窄边设计显得屏幕更大，画质清晰 比一般4k电视色彩更丰富，智能界面简洁易操作，风行资源够多，也可以自己下载软件。风行网络资源没得说电影电视剧 少儿节目都很多而且操作简单 老人学起来都很方便，买之前对比很多只能电视 现在看来风行物有所值！ 正面 正面
# 性价比不错 正面 正面
# 物流太差了，本省的配送点走了5天，服务态度不是很好，习惯性好评 负面 负面
# 货品已经收到了，色彩挺好的就是没有之前买的45寸的价格实惠，但是跟实体店的价格比便宜多了 正面 正面
# 电视刚买回来的时候那段时间遥控器经常失灵，有一会可以一会又不行，申请师傅上门安装师傅打电话给我你要安装调什么，无语我要是全能要你们干嘛？搞的来火自己解决，微鲸售后服务是不咋地。 负面 负面
# 因为我自己双十一买了台55寸的、觉得很不错、双十二给哥哥买了台43寸的、原本想买49寸的、结果49寸当天停售一样的、浙江台州、武汉全没货、没办法就买了43寸的 正面 正面
# 置却不低。送货快，快递员帮着开箱检查，没找到什么毛病，屏幕色彩亮丽无坏点。再说缺点：有了电脑的性能就有了电脑的毛病，开机慢（15秒左右），有一次开机居然还死机了。没有vga接口。屏幕反光大些。用料差些，看那单薄的电源线和插头就知道了。最大的糟点还是声音干巴刺耳，就好象音箱只装了高音而没有中低音喇叭，而且机器没有外接音箱口。当然一分钱一分货，也不好再多挑剔了。 负面 负面
# 电视不错，性价比超高，虽然没有双11划算，但已经很超值了 正面 正面
# 昨天晚上下单 今天下午收到电视机 自己安装上底座 直接连接的wifi没有接机顶盒 操作很方便 百视通的影视资源足够丰富 喜欢看的影视剧和综艺都有 电视机色彩丰富 运行内存虽然不大 但是我觉得没必要安装第三方app 所以使用上没问题 总之很满意的一次购物 晒单： 收起 向左转 向右转 正面 正面
# 给家里老人买的，很不错哦，价格实惠 正面 正面
# 给父母买的，特意用了一段时间再来评价，电视非常好，没有坏点和损坏，界面也很简洁，便于操作，稍微不足就是开机会比普通电视慢一些，这应该是智能电视的通病吧，如果可以希望微鲸大大可以更新系统优化下开机时间~电视真的很棒，性价比爆棚，值得大家考虑购买。 客服很细心，快递小哥很耐心的等我通电验货，态度非常好。 负面 正面
# 长须鲸和海狮回答都很及时，虽然物流不够快但是服务不错电视不错，对比了乐视小米和微鲸论性价比还是微鲸好点 负面 负面
# 所以看不到4k效果，但是应该可以。 自带音响，中规中矩吧，好像没有别人说的好。而且，到现在没连接上我的漫步者，这个非常不满意，因为看到网上说好像普通3.5mm的连不上或者连上了声音小。希望厂家接下来开发的电视有改进。不知道我要不要换个音响。其他的用用再说。 放在地上的是跟我混了两年的tcl，天气受潮，修了一次，下岗了。 最后，我也觉得底座不算太稳，凑合着用。 负面 负面
# 电视机一般，低端机不要求那么高咯。 负面 负面
# 很好，两点下单上午就到了，服务很好。 正面 正面
# 帮朋友买的，好好好好好好好好 正面 正面
# 模型在测试集上的准确率为: 0.9137529137529138.
